# %% [raw]
# 本文件用于配置G-eval需要的环境

# %% [raw]
# Cell 0：先确认 notebook 用的是哪个 python

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# /opt/conda/bin/python
# 3.11.0 (main, Mar  1 2023, 18:26:19) [GCC 11.2.0]
# python: /opt/conda/bin/python
# version: 3.11.0 (main, Mar  1 2023, 18:26:19) [GCC 11.2.0]

# %% [raw]
# Cell 1：卸载残留 + 安装兼容组合

# %%
import sys

# !{sys.executable} -m pip uninstall -y transformers tokenizers
# !{sys.executable} -m pip install -U "transformers==4.56.2" "tokenizers==0.22.1"
# Out:
# WARNING: Skipping transformers as it is not installed.
# WARNING: Skipping tokenizers as it is not installed.
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/70/26/2591b48412bde75e33bfd292034103ffe41743cacd03120e3242516cd143/transformers-4.56.2-py3-none-any.whl (11.6 MB)
# ...
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/d0/c6/dc3a0db5a6766416c32c034286d7c2d406da1f498e4de04ab1b8959edd00/tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# ...
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/cb/bd/1a875e0d592d447cbc02805fd3fe0f497714d6a2583f59d14fa9ebad96eb/huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.17.0
#     Uninstalling huggingface-hub-0.17.0:
#       Successfully uninstalled huggingface-hub-0.17.0
# ...

# %% [raw]
# Cell 2：重启 kernel

# %%
import os, signal
os.kill(os.getpid(), signal.SIGKILL)

# %% [raw]
# Cell 3：验证transformers 能 import ✅，tokenizers 是 0.22.x ✅，ALLOWED_LAYER_TYPES 存在

# %%
import transformers, tokenizers
import transformers.configuration_utils as cu
print("transformers:", transformers.__version__)
print("tokenizers:", tokenizers.__version__)
print("ALLOWED_LAYER_TYPES:", hasattr(cu, "ALLOWED_LAYER_TYPES"))
# Out:
# transformers: 4.56.2
# tokenizers: 0.22.1
# ALLOWED_LAYER_TYPES: True

# %%
#验证：vLLM 能 import
import vllm
print("vllm:", vllm.__version__)
# Out:
# vllm: 0.13.0
